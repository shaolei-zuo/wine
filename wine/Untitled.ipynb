# %%
#https://tianchi.aliyun.com/notebook-ai/detail?spm=5176.12282042.0.0.1dc6290aLQ1FQS&postId=4662
#数据来源：http://archive.ics.uci.edu/ml/datasets/Wine+Quality
#相关paper: https://www.sciencedirect.com/science/article/pii/S0167923609001377
#红酒数据分析-我的与天池模板

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# 颜色
color = sns.color_palette()
# 数据print精度
pd.set_option('precision',3) 

# set plot style
plt.style.use('ggplot')

# %%
dfr.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'total acid', 'sweetness',
#        'lev'],
#       dtype='object')

# %%
dfr = pd.read_csv('./data/winequality-red.csv',sep = ';')
dfw = pd.read_csv('./data/winequality-white.csv',sep = ';')

# %% [markdown]
# ### 看一下列

# %% [markdown]
# 1 fixed acidity: 非挥发性酸
# 2 volatile acidity: 挥发性酸
# 3 citric acid ：柠檬酸
# 4 residual sugar：残糖
# 5 chlorides：氯化物
# 6 free sulfur dioxide：游离二氧化硫
# 7 total sulfur dioxide：总二氧化硫
# 8 density：密度
# 9 pH：ph
# 10 sulphates:硫酸盐
# 11 alcohol：醇
#
# Output variable (based on sensory data):
# 12 - quality (score between 0 and 10)：质量

# %% [markdown]
# ---
# 同一品种，变量之间的关系（各自的，相互的），变量的特征
# 不同品种，变量之间的关系（互相对应）
#
# ### Q1:什么组合会得到好的评分
# ### Q2:特征之间有没有关联性
# ### Q3:红酒与白酒之间组合上的异同是什么

# %%
dfr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
# fixed acidity           1599 non-null float64
# volatile acidity        1599 non-null float64
# citric acid             1599 non-null float64
# residual sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free sulfur dioxide     1599 non-null float64
# total sulfur dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# # 单变量分析

# %%
dfr.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count       1599.000          1599.000     1599.000        1599.000
# mean           8.320             0.528        0.271           2.539
# std            1.741             0.179        0.195           1.410
# min            4.600             0.120        0.000           0.900
# 25%            7.100             0.390        0.090           1.900
# 50%            7.900             0.520        0.260           2.200
# 75%            9.200             0.640        0.420           2.600
# max           15.900             1.580        1.000          15.500
#
#        chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# count   1599.000             1599.000              1599.000  1599.000
# mean       0.087               15.875                46.468     0.997
# std        0.047               10.460                32.895     0.002
# min        0.012                1.000                 6.000     0.990
# ...

# %%
colnm = dfr.columns.tolist()
fig = plt.figure(figsize = (10, 6))

for i in range(12):
    plt.subplot(2,6,i+1)
    sns.boxplot(dfr[colnm[i]], orient="v", width = 0.5, color = color[0])
    plt.ylabel(colnm[i],fontsize = 12)
#plt.subplots_adjust(left=0.2, wspace=0.8, top=0.9)

plt.tight_layout()
print('\nFigure 1: Univariate Boxplots')
# Out:
# Figure 1: Univariate Boxplots

# %%
plt.figure(figsize = (10, 8))

for i in range(12):
    plt.subplot(4,3,i+1)
    dfr[colnm[i]].hist(bins = 100, color = color[0])
    plt.xlabel(colnm[i],fontsize = 12)
    plt.ylabel('Frequency')
plt.tight_layout()
print('\nFigure 2: Univariate Histograms')
# Out:
# Figure 2: Univariate Histograms

# %% [markdown]
# - 浏览数据时，最好有相关的知识储备。
# - 比如影响葡萄酒口感的因素有甜度、酸度、单宁、酒精、酒体、香气这六种.
# - 样本相关的有甜度、酸度、酒精

# %% [markdown]
# ## 酸度
#
# 这个数据集有7个酸度相关的特征：fixed acidity, volatile acidity, citric acid, free sulfur dioxide, total sulfur dioxide, sulphates, pH。前6个特征都与红酒的pH的相关。pH是在对数的尺度，下面对前6个特征取对数然后作histogram。
# 可知，pH值主要是与fixed acidity有关，fixed acidity比volatile acidity和citric acid高1到2个数量级(Figure 4)，比free sulfur dioxide, total sulfur dioxide, sulphates高3个数量级。一个新特征total acid来自于前三个特征的和。

# %%
acidityFeat = ['fixed acidity', 'volatile acidity', 'citric acid',
               'free sulfur dioxide', 'total sulfur dioxide', 'sulphates']

plt.figure(figsize = (10, 4))

for i in range(6):
    ax = plt.subplot(2,3,i+1)
    v = np.log10(np.clip(dfr[acidityFeat[i]].values, a_min = 0.001, a_max = None))
    plt.hist(v, bins = 50, color = color[0])
    plt.xlabel('log(' + acidityFeat[i] + ')',fontsize = 12)

    plt.ylabel('Frequency')
plt.tight_layout()
print('\nFigure 3: Acidity Features in log10 Scale')
# Out:
# Figure 3: Acidity Features in log10 Scale

# %%
plt.figure(figsize=(6,3))

bins = 10**(np.linspace(-2, 2))
plt.hist(dfr['fixed acidity'], bins = bins, edgecolor = 'k', label = 'Fixed Acidity')
plt.hist(dfr['volatile acidity'], bins = bins, edgecolor = 'k', label = 'Volatile Acidity')
plt.hist(dfr['citric acid'], bins = bins, edgecolor = 'k', alpha = 0.8, label = 'Citric Acid')
plt.xscale('log')
plt.xlabel('Acid Concentration (g/dm^3)')
plt.ylabel('Frequency')
plt.title('Histogram of Acid Concentration')
plt.legend()
plt.tight_layout()

print('Figure 4')
# Out:
# Figure 4

# %%
# 总酸度
dfr['total acid'] = dfr['fixed acidity'] + dfr['volatile acidity'] + dfr['citric acid']

# %%
plt.figure(figsize = (8,3))

plt.subplot(121)
plt.hist(dfr['total acid'], bins = 50, color = color[0])
plt.xlabel('total acid')
plt.ylabel('Frequency')
plt.subplot(122)
plt.hist(np.log(dfr['total acid']), bins = 50 , color = color[0])
plt.xlabel('log(total acid)')
plt.ylabel('Frequency')
plt.tight_layout()

print("Figure 5: Total Acid Histogram")
# Out:
# Figure 5: Total Acid Histogram

# %% [markdown]
# # 甜度

# %% [markdown]
# Residual sugar 与酒的甜度相关，通常用来区别各种红酒，干红（<=4 g/L), 半干（4-12 g/L）,半甜（12-45 g/L），和甜（>45 g/L)。 这个数据中，主要为干红，没有甜葡萄酒。

# %%
# Residual sugar
dfr['sweetness'] = pd.cut(dfr['residual sugar'], bins = [0, 4, 12, 45], 
                         labels=["dry", "medium dry", "semi-sweet"])

# %%
plt.figure(figsize = (5,3))
dfr['sweetness'].value_counts().plot(kind = 'bar', color = color[0])
plt.xticks(rotation=0)
plt.xlabel('sweetness', fontsize = 12)
plt.ylabel('Frequency', fontsize = 12)
plt.tight_layout()
print("Figure 6: Sweetness")
# Out:
# Figure 6: Sweetness

# %% [markdown]
# # 双变量分析

# %% [markdown]
# ## 红酒品质和理化特征的关系
#
# 下面Figure 7和8分别显示了红酒理化特征和品质的关系。其中可以看出的趋势有：
#
# -   品质好的酒有更高的柠檬酸，硫酸盐，和酒精度数。硫酸盐(硫酸钙)的加入通常是调整酒的酸度的。其中酒精度数和品质的相关性最高。
# -    品质好的酒有较低的挥发性酸类，密度，和pH。
# -    残留糖分，氯离子，二氧化硫似乎对酒的品质影响不大。

# %%
sns.set_style('ticks')
sns.set_context("notebook", font_scale= 1.1)

colnm = dfr.columns.tolist()[:11] + ['total acid']
plt.figure(figsize = (10, 8))

for i in range(12):
    plt.subplot(4,3,i+1)
    sns.boxplot(x ='quality', y = colnm[i], data = dfr, color = color[0], width = 0.6)    
    plt.ylabel(colnm[i],fontsize = 12)
plt.tight_layout()
print("\nFigure 7: Physicochemical Properties and Wine Quality by Boxplot")
# Out:
# Figure 7: Physicochemical Properties and Wine Quality by Boxplot

# %%
#sns.set_style("dark")

plt.figure(figsize = (10,8))
colnm = dfr.columns.tolist()[:11] + ['total acid', 'quality']
mcorr = dfr[colnm].corr()
mask = np.zeros_like(mcorr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
cmap = sns.diverging_palette(220, 10, as_cmap=True)
g = sns.heatmap(mcorr, mask=mask, cmap=cmap, square=True, annot=True, fmt='0.2f')
print("\nFigure 8: Pairwise Correlation Plot")
# Out:
# Figure 8: Pairwise Correlation Plot

# %% [markdown]
# # 密度和酒精浓度
#
# 密度和酒精浓度是相关的，物理
# 上，两者并不是线性关系。Figure 8展示了两者的关系。另外密度还与酒中其他物质的含量有关，但是关系很小。

# %%
# style
sns.set_style('ticks')
sns.set_context("notebook", font_scale= 1.4)

# plot figure
plt.figure(figsize = (6,4))
sns.regplot(x='density', y = 'alcohol', data = dfr, scatter_kws = {'s':10}, color = color[0])
plt.xlim(0.989, 1.005)
plt.ylim(7,16)
print('Figure 9: Density vs Alcohol')
# Out:
# Figure 9: Density vs Alcohol

# %% [markdown]
# # 酸性物质含量和pH
#
# pH和非挥发性酸性物质有-0.683的相关性。因为非挥发性酸性物质的含量远远高于其他酸性物质，总酸性物质(total acidity)这个特征并没有太多意义。

# %%
acidity_related = ['fixed acidity', 'volatile acidity', 'total sulfur dioxide', 
                   'sulphates', 'total acid']
plt.figure(figsize=(10,6))
for i in range(len(acidity_related)):
    plt.subplot(2,3,i+1)
    sns.regplot(x = 'pH',y=acidity_related[i],scatter_kws={'s':10} ,data=dfr)
    plt.ylabel(acidity_related[i],fontsize = 10)
plt.tight_layout()

# %% [markdown]
# # 多变量分析
# 与品质相关性最高的三个特征是酒精浓度，挥发性酸度，和柠檬酸。下面图中显示的酒精浓度，挥发性酸和品质的关系。
#
# ## 酒精浓度，挥发性酸和品质
# 对于好酒（7，8）以及差酒（3，4），关系很明显。但是对于中等酒（5，6），酒精浓度的挥发性酸度有很大程度的交叉

# %%
#plt.style.use('ggplot')

plt.figure(figsize=(10,25))
sns.lmplot(x = 'alcohol', y = 'volatile acidity', hue = 'quality', 
           data = dfr, fit_reg = False, scatter_kws={'s':10},height=7)
print("Figure 11-1: Scatter Plots of Alcohol, Volatile Acid and Quality")
# Out:
# Figure 11-1: Scatter Plots of Alcohol, Volatile Acid and Quality

# %%
dfr['lev'] = pd.cut(dfr['quality'],labels=[4,6,8],bins=3)
sns.lmplot(x = 'alcohol',y = 'volatile acidity', hue = 'lev',data = dfr,fit_reg=False,height=7)

# %%
sns.lmplot(x = 'alcohol', y = 'volatile acidity', col='quality', hue = 'quality', 
           data = dfr,fit_reg = False, height = 3,  aspect = 0.9, col_wrap=3,
           scatter_kws={'s':20})
print("Figure 11-2: Scatter Plots of Alcohol, Volatile Acid and Quality")
# Out:
# Figure 11-2: Scatter Plots of Alcohol, Volatile Acid and Quality

# %%
sns.lmplot(x = 'alcohol', y = 'volatile acidity', col='lev', hue = 'quality', 
           data = dfr,fit_reg = False, height = 3,  aspect = 0.9, col_wrap=3,
           scatter_kws={'s':20})
print("Figure 11-2: Scatter Plots of Alcohol, Volatile Acid and Quality")
# Out:
# Figure 11-2: Scatter Plots of Alcohol, Volatile Acid and Quality

# %% [markdown]
# # pH，非挥发性酸，和柠檬酸
# pH和非挥发性的酸以及柠檬酸有相关性。整体趋势也很合理，即浓度越高，pH越低。

# %%
# style
sns.set_style('ticks')
sns.set_context("notebook", font_scale= 1.4)

plt.figure(figsize=(6,5))
cm = plt.cm.get_cmap('RdBu')
sc = plt.scatter(dfr['fixed acidity'], dfr['citric acid'], c=dfr['pH'], vmin=2.6, vmax=4, s=15, cmap=cm)
bar = plt.colorbar(sc)
bar.set_label('pH', rotation = 0)
plt.xlabel('fixed acidity')
plt.ylabel('citric acid')
plt.xlim(4,18)
plt.ylim(0,1)
print('Figure 12: pH with Fixed Acidity and Citric Acid')
# Out:
# Figure 12: pH with Fixed Acidity and Citric Acid
